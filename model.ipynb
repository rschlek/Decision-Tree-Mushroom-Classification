# %% [markdown]
# # Mushroom Classification Decision Tree
#
# Importing Modules

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

# %% [markdown]
# Reading in dataset

# %%
df = pd.read_csv('mushrooms.csv')

df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %% [markdown]
# Checking for missing data

# %%
df.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# Data Preprocessing

# %%
le = LabelEncoder()
df = df.apply(LabelEncoder().fit_transform)

df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
'''
Passes data, train/test split ratio, max_depth parameters, and criterion

Function splits randomly into train/test, and returns the evaluated score of the decision tree model
'''
def build_decision_tree(ratio, max_depth=None,criterion='gini',df=df):
    output = df['class']
    no_output = df.drop(['class'], axis=1)
    x_train, x_test, y_train, y_test = train_test_split(no_output, output, test_size=ratio)

    if criterion != 'gini' and criterion != 'entropy':
        print('Invalid criterion')
        return None


    model = DecisionTreeClassifier(max_depth=max_depth,criterion=criterion)
    model.fit(x_train, y_train)
    predict = model.predict(x_test)
    accuracy = accuracy_score(y_test, predict)
    
    return accuracy

# %%
def build_random_forest(ratio, n_estimators = 130, max_depth=None, criterion='gini', df=df):
    output = df['class']
    no_output = df.drop(['class'], axis=1)
    x_train, x_test, y_train, y_test = train_test_split(no_output, output, test_size=ratio)
    
    if criterion != 'gini' and criterion != 'entropy':
        print('Invalid criterion')
        return None

    model = RandomForestClassifier(max_depth=max_depth,n_estimators=n_estimators,criterion=criterion)
    model.fit(x_train, y_train)
    predict = model.predict(x_test)
    accuracy = accuracy_score(y_test,predict)

    return accuracy

# %%
columns = ['Model Type', 'Training Split Ratio', 'Max Depth', 'Criterion', 'Number of Trees', 'Mean Accuracy']
results = pd.DataFrame(columns=columns)

# %%
test_ratios = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45]
test_criterion = ['gini','entropy']
test_depth = [1,2,3,4,5,6]
num_trees = 130 # Tests number of trees from 130 to num_trees (must 130 ir greater)

# %%
def test_decision_tree(tests):
    global results
    for ratio in test_ratios:
        for criterion in test_criterion:
            for depth in test_depth:
                accuracy_sum = 0
                completed_tests = 0
                while completed_tests < tests:
                    accuracy_sum += build_decision_tree(ratio,depth,criterion)
                    completed_tests += 1
                mean_accuracy = accuracy_sum / tests
                new_row = {'Model Type': 'Decision Tree', 'Training Split Ratio': ratio, 'Max Depth': depth, 'Criterion': criterion, 'Number of Trees': np.nan, 'Mean Accuracy': mean_accuracy}
                results = results.append(new_row,ignore_index=True)
                print('Decision Tree Test: ', ratio, criterion, depth, 'completed with an accuracy of ', mean_accuracy)

# %%
def test_forest(tests):
    global results
    for ratio in test_ratios:
        for criterion in test_criterion:
            for depth in test_depth:
                for trees in range(125,num_trees+1):
                    accuracy_sum = 0
                    completed_tests = 0
                    while completed_tests < tests:
                        accuracy_sum += build_random_forest(ratio,trees,depth,criterion)
                        completed_tests += 1
                    mean_accuracy = accuracy_sum / tests
                    new_row = {'Model Type': 'Random Forest', 'Training Split Ratio': ratio, 'Max Depth': depth, 'Criterion': criterion, 'Number of Trees': trees, 'Mean Accuracy': mean_accuracy}
                    results = results.append(new_row,ignore_index=True)
                    print('Forest Test: ', ratio, criterion, depth, trees, 'completed with an accuracy of ', mean_accuracy)

# %%
def test(tests):
    test_decision_tree(tests)
    test_forest(tests)

# %%
test(100)

results = results.sort_values(by='Mean Accuracy',ascending=False)
results = results[results['Mean Accuracy'] != 1.0]
results.to_csv('results.csv',index=False)
# Out:
# Decision Tree Test:  0.1 gini 1 completed with an accuracy of  0.7918327183271834
# Decision Tree Test:  0.1 gini 2 completed with an accuracy of  0.9108364083640833
# Decision Tree Test:  0.1 gini 3 completed with an accuracy of  0.9578228782287824
# Decision Tree Test:  0.1 gini 4 completed with an accuracy of  0.9764821648216483
# Decision Tree Test:  0.1 gini 5 completed with an accuracy of  0.9789052890528903
# Decision Tree Test:  0.1 gini 6 completed with an accuracy of  0.9953751537515377
# Decision Tree Test:  0.1 entropy 1 completed with an accuracy of  0.7336039360393605
# Decision Tree Test:  0.1 entropy 2 completed with an accuracy of  0.9123247232472328
# Decision Tree Test:  0.1 entropy 3 completed with an accuracy of  0.956088560885609
# Decision Tree Test:  0.1 entropy 4 completed with an accuracy of  0.9536900369003692
# Decision Tree Test:  0.1 entropy 5 completed with an accuracy of  0.9770356703567039
# Decision Tree Test:  0.1 entropy 6 completed with an accuracy of  0.991709717097171
# Decision Tree Test:  0.15 gini 1 completed with an accuracy of  0.7897785069729286
# Decision Tree Test:  0.15 gini 2 completed with an accuracy of  0.9098933552091879
# Decision Tree Test:  0.15 gini 3 completed with an accuracy of  0.9585151763740772
# Decision Tree Test:  0.15 gini 4 completed with an accuracy of  0.977366694011485
# Decision Tree Test:  0.15 gini 5 completed with an accuracy of  0.9794995898277277
# Decision Tree Test:  0.15 gini 6 completed with an accuracy of  0.9954388843314192
# Decision Tree Test:  0.15 entropy 1 completed with an accuracy of  0.7303363412633306
# Decision Tree Test:  0.15 entropy 2 completed with an accuracy of  0.9138966365873665
# Decision Tree Test:  0.15 entropy 3 completed with an accuracy of  0.9568990976210009
# Decision Tree Test:  0.15 entropy 4 completed with an accuracy of  0.9553978671041837
# Decision Tree Test:  0.15 entropy 5 completed with an accuracy of  0.9777768662838393
# Decision Tree Test:  0.15 entropy 6 completed with an accuracy of  0.9917145200984419
# Decision Tree Test:  0.2 gini 1 completed with an accuracy of  0.7898584615384618
# Decision Tree Test:  0.2 gini 2 completed with an accuracy of  0.9108738461538458
# Decision Tree Test:  0.2 gini 3 completed with an accuracy of  0.9580492307692313
# Decision Tree Test:  0.2 gini 4 completed with an accuracy of  0.977993846153846
# Decision Tree Test:  0.2 gini 5 completed with an accuracy of  0.9793169230769233
# Decision Tree Test:  0.2 gini 6 completed with an accuracy of  0.9957723076923081
# Decision Tree Test:  0.2 entropy 1 completed with an accuracy of  0.7355815384615384
# Decision Tree Test:  0.2 entropy 2 completed with an accuracy of  0.9131199999999999
# Decision Tree Test:  0.2 entropy 3 completed with an accuracy of  0.9573476923076925
# Decision Tree Test:  0.2 entropy 4 completed with an accuracy of  0.9567384615384615
# Decision Tree Test:  0.2 entropy 5 completed with an accuracy of  0.9774584615384617
# Decision Tree Test:  0.2 entropy 6 completed with an accuracy of  0.9918646153846161
# Decision Tree Test:  0.25 gini 1 completed with an accuracy of  0.7901378631216147
# Decision Tree Test:  0.25 gini 2 completed with an accuracy of  0.9103938946331859
# Decision Tree Test:  0.25 gini 3 completed with an accuracy of  0.9583653372722797
# Decision Tree Test:  0.25 gini 4 completed with an accuracy of  0.9777498769079276
# Decision Tree Test:  0.25 gini 5 completed with an accuracy of  0.9788380108321029
# Decision Tree Test:  0.25 gini 6 completed with an accuracy of  0.9957163958641067
# Decision Tree Test:  0.25 entropy 1 completed with an accuracy of  0.7389414081733138
# Decision Tree Test:  0.25 entropy 2 completed with an accuracy of  0.912954209748892
# Decision Tree Test:  0.25 entropy 3 completed with an accuracy of  0.9568833087149187
# Decision Tree Test:  0.25 entropy 4 completed with an accuracy of  0.9577252584933531
# Decision Tree Test:  0.25 entropy 5 completed with an accuracy of  0.9782865583456426
# Decision Tree Test:  0.25 entropy 6 completed with an accuracy of  0.9928902018709997
# Decision Tree Test:  0.3 gini 1 completed with an accuracy of  0.7906357670221495
# Decision Tree Test:  0.3 gini 2 completed with an accuracy of  0.9110992616899094
# Decision Tree Test:  0.3 gini 3 completed with an accuracy of  0.9587776866283838
# Decision Tree Test:  0.3 gini 4 completed with an accuracy of  0.9775881870385565
# Decision Tree Test:  0.3 gini 5 completed with an accuracy of  0.979191960623462
# Decision Tree Test:  0.3 gini 6 completed with an accuracy of  0.9952214930270717
# Decision Tree Test:  0.3 entropy 1 completed with an accuracy of  0.7326292042657918
# Decision Tree Test:  0.3 entropy 2 completed with an accuracy of  0.9138679245283019
# Decision Tree Test:  0.3 entropy 3 completed with an accuracy of  0.9564930270713696
# Decision Tree Test:  0.3 entropy 4 completed with an accuracy of  0.9580434782608696
# Decision Tree Test:  0.3 entropy 5 completed with an accuracy of  0.9780311730926989
# Decision Tree Test:  0.3 entropy 6 completed with an accuracy of  0.9913658736669403
# Decision Tree Test:  0.35 gini 1 completed with an accuracy of  0.790973980309423
# Decision Tree Test:  0.35 gini 2 completed with an accuracy of  0.910537974683544
# Decision Tree Test:  0.35 gini 3 completed with an accuracy of  0.9579606188466944
# Decision Tree Test:  0.35 gini 4 completed with an accuracy of  0.9778797468354431
# Decision Tree Test:  0.35 gini 5 completed with an accuracy of  0.9792791842475387
# Decision Tree Test:  0.35 gini 6 completed with an accuracy of  0.9961286919831224
# Decision Tree Test:  0.35 entropy 1 completed with an accuracy of  0.7415893108298169
# Decision Tree Test:  0.35 entropy 2 completed with an accuracy of  0.9134985935302393
# Decision Tree Test:  0.35 entropy 3 completed with an accuracy of  0.9565365682137841
# Decision Tree Test:  0.35 entropy 4 completed with an accuracy of  0.9596554149085793
# Decision Tree Test:  0.35 entropy 5 completed with an accuracy of  0.9783333333333337
# Decision Tree Test:  0.35 entropy 6 completed with an accuracy of  0.9924578059071734
# Decision Tree Test:  0.4 gini 1 completed with an accuracy of  0.790150769230769
# Decision Tree Test:  0.4 gini 2 completed with an accuracy of  0.9110307692307695
# Decision Tree Test:  0.4 gini 3 completed with an accuracy of  0.9589969230769229
# Decision Tree Test:  0.4 gini 4 completed with an accuracy of  0.9765630769230768
# Decision Tree Test:  0.4 gini 5 completed with an accuracy of  0.9789415384615385
# Decision Tree Test:  0.4 gini 6 completed with an accuracy of  0.9951999999999999
# Decision Tree Test:  0.4 entropy 1 completed with an accuracy of  0.7432153846153846
# Decision Tree Test:  0.4 entropy 2 completed with an accuracy of  0.9128769230769228
# Decision Tree Test:  0.4 entropy 3 completed with an accuracy of  0.9572061538461542
# Decision Tree Test:  0.4 entropy 4 completed with an accuracy of  0.9593353846153845
# Decision Tree Test:  0.4 entropy 5 completed with an accuracy of  0.9782615384615384
# Decision Tree Test:  0.4 entropy 6 completed with an accuracy of  0.992181538461539
# Decision Tree Test:  0.45 gini 1 completed with an accuracy of  0.7896799781181624
# Decision Tree Test:  0.45 gini 2 completed with an accuracy of  0.9110147702407001
# Decision Tree Test:  0.45 gini 3 completed with an accuracy of  0.9586816192560176
# Decision Tree Test:  0.45 gini 4 completed with an accuracy of  0.9757932166301966
# Decision Tree Test:  0.45 gini 5 completed with an accuracy of  0.9789277899343545
# Decision Tree Test:  0.45 gini 6 completed with an accuracy of  0.9958233041575485
# Decision Tree Test:  0.45 entropy 1 completed with an accuracy of  0.745459518599562
# Decision Tree Test:  0.45 entropy 2 completed with an accuracy of  0.913142778993435
# Decision Tree Test:  0.45 entropy 3 completed with an accuracy of  0.9571471553610498
# Decision Tree Test:  0.45 entropy 4 completed with an accuracy of  0.9609463894967178
# Decision Tree Test:  0.45 entropy 5 completed with an accuracy of  0.9784190371991253
# Decision Tree Test:  0.45 entropy 6 completed with an accuracy of  0.9937746170678338
# Forest Test:  0.1 gini 1 125 completed with an accuracy of  0.8831242312423124
# Forest Test:  0.1 gini 1 126 completed with an accuracy of  0.8819065190651909
# Forest Test:  0.1 gini 1 127 completed with an accuracy of  0.8791881918819193
# Forest Test:  0.1 gini 1 128 completed with an accuracy of  0.8801968019680195
# Forest Test:  0.1 gini 1 129 completed with an accuracy of  0.8831365313653134
# Forest Test:  0.1 gini 1 130 completed with an accuracy of  0.8817343173431738
# Forest Test:  0.1 gini 2 125 completed with an accuracy of  0.9227429274292749
# Forest Test:  0.1 gini 2 126 completed with an accuracy of  0.9236654366543666
# Forest Test:  0.1 gini 2 127 completed with an accuracy of  0.9221279212792127
# Forest Test:  0.1 gini 2 128 completed with an accuracy of  0.9228782287822881
# Forest Test:  0.1 gini 2 129 completed with an accuracy of  0.9229274292742928
# Forest Test:  0.1 gini 2 130 completed with an accuracy of  0.9228167281672813
# Forest Test:  0.1 gini 3 125 completed with an accuracy of  0.9825584255842557
# Forest Test:  0.1 gini 3 126 completed with an accuracy of  0.982632226322263
# Forest Test:  0.1 gini 3 127 completed with an accuracy of  0.9820664206642058
# Forest Test:  0.1 gini 3 128 completed with an accuracy of  0.982841328413284
# Forest Test:  0.1 gini 3 129 completed with an accuracy of  0.9825707257072567
# Forest Test:  0.1 gini 3 130 completed with an accuracy of  0.982988929889299
# Forest Test:  0.1 gini 4 125 completed with an accuracy of  0.9904920049200497
# Forest Test:  0.1 gini 4 126 completed with an accuracy of  0.9903690036900372
# Forest Test:  0.1 gini 4 127 completed with an accuracy of  0.9896432964329643
# Forest Test:  0.1 gini 4 128 completed with an accuracy of  0.99
# Forest Test:  0.1 gini 4 129 completed with an accuracy of  0.9901230012300125
# Forest Test:  0.1 gini 4 130 completed with an accuracy of  0.9903075030750308
# Forest Test:  0.1 gini 5 125 completed with an accuracy of  0.9910455104551051
# Forest Test:  0.1 gini 5 126 completed with an accuracy of  0.9908979089790896
# Forest Test:  0.1 gini 5 127 completed with an accuracy of  0.9911193111931125
# Forest Test:  0.1 gini 5 128 completed with an accuracy of  0.9901230012300124
# Forest Test:  0.1 gini 5 129 completed with an accuracy of  0.9903936039360391
# Forest Test:  0.1 gini 5 130 completed with an accuracy of  0.9903690036900369
# Forest Test:  0.1 gini 6 125 completed with an accuracy of  0.9939360393603942
# Forest Test:  0.1 gini 6 126 completed with an accuracy of  0.994120541205412
# Forest Test:  0.1 gini 6 127 completed with an accuracy of  0.9933948339483402
# Forest Test:  0.1 gini 6 128 completed with an accuracy of  0.9942312423124234
# Forest Test:  0.1 gini 6 129 completed with an accuracy of  0.9935424354243547
# Forest Test:  0.1 gini 6 130 completed with an accuracy of  0.9937638376383766
# Forest Test:  0.1 entropy 1 125 completed with an accuracy of  0.8963099630996311
# Forest Test:  0.1 entropy 1 126 completed with an accuracy of  0.8956703567035672
# Forest Test:  0.1 entropy 1 127 completed with an accuracy of  0.8924723247232471
# Forest Test:  0.1 entropy 1 128 completed with an accuracy of  0.8933948339483393
# Forest Test:  0.1 entropy 1 129 completed with an accuracy of  0.8946863468634682
# Forest Test:  0.1 entropy 1 130 completed with an accuracy of  0.8959532595325949
# Forest Test:  0.1 entropy 2 125 completed with an accuracy of  0.9233825338253382
# Forest Test:  0.1 entropy 2 126 completed with an accuracy of  0.917847478474785
# Forest Test:  0.1 entropy 2 127 completed with an accuracy of  0.9185485854858548
# Forest Test:  0.1 entropy 2 128 completed with an accuracy of  0.918966789667897
# Forest Test:  0.1 entropy 2 129 completed with an accuracy of  0.9217097170971708
# Forest Test:  0.1 entropy 2 130 completed with an accuracy of  0.9227552275522756
# Forest Test:  0.1 entropy 3 125 completed with an accuracy of  0.9818450184501846
# Forest Test:  0.1 entropy 3 126 completed with an accuracy of  0.9813653136531362
# Forest Test:  0.1 entropy 3 127 completed with an accuracy of  0.9817343173431736
# Forest Test:  0.1 entropy 3 128 completed with an accuracy of  0.9796432964329642
# Forest Test:  0.1 entropy 3 129 completed with an accuracy of  0.98150061500615
# Forest Test:  0.1 entropy 3 130 completed with an accuracy of  0.9800369003690037
# Forest Test:  0.1 entropy 4 125 completed with an accuracy of  0.9894095940959409
# Forest Test:  0.1 entropy 4 126 completed with an accuracy of  0.989667896678967
# Forest Test:  0.1 entropy 4 127 completed with an accuracy of  0.9898892988929892
# Forest Test:  0.1 entropy 4 128 completed with an accuracy of  0.9890651906519065
# Forest Test:  0.1 entropy 4 129 completed with an accuracy of  0.9895694956949572
# Forest Test:  0.1 entropy 4 130 completed with an accuracy of  0.9897170971709716
# Forest Test:  0.1 entropy 5 125 completed with an accuracy of  0.9894341943419431
# Forest Test:  0.1 entropy 5 126 completed with an accuracy of  0.9904305043050432
# Forest Test:  0.1 entropy 5 127 completed with an accuracy of  0.9902337023370233
# Forest Test:  0.1 entropy 5 128 completed with an accuracy of  0.990381303813038
# Forest Test:  0.1 entropy 5 129 completed with an accuracy of  0.9902337023370237
# Forest Test:  0.1 entropy 5 130 completed with an accuracy of  0.9901107011070112
# Forest Test:  0.1 entropy 6 125 completed with an accuracy of  0.9922509225092252
# Forest Test:  0.1 entropy 6 126 completed with an accuracy of  0.9917712177121775
# Forest Test:  0.1 entropy 6 127 completed with an accuracy of  0.991660516605167
# Forest Test:  0.1 entropy 6 128 completed with an accuracy of  0.9916113161131616
# Forest Test:  0.1 entropy 6 129 completed with an accuracy of  0.9918573185731856
# Forest Test:  0.1 entropy 6 130 completed with an accuracy of  0.9917343173431737
# Forest Test:  0.15 gini 1 125 completed with an accuracy of  0.8805250205086139
# Forest Test:  0.15 gini 1 126 completed with an accuracy of  0.8829122231337163
# Forest Test:  0.15 gini 1 127 completed with an accuracy of  0.8812223133716164
# Forest Test:  0.15 gini 1 128 completed with an accuracy of  0.8820262510254309
# Forest Test:  0.15 gini 1 129 completed with an accuracy of  0.8837243642329775
# Forest Test:  0.15 gini 1 130 completed with an accuracy of  0.8824610336341264
# Forest Test:  0.15 gini 2 125 completed with an accuracy of  0.9222231337161608
# Forest Test:  0.15 gini 2 126 completed with an accuracy of  0.922608695652174
# Forest Test:  0.15 gini 2 127 completed with an accuracy of  0.9207465135356852
# Forest Test:  0.15 gini 2 128 completed with an accuracy of  0.9205988515176375
# Forest Test:  0.15 gini 2 129 completed with an accuracy of  0.9203609515996716
# Forest Test:  0.15 gini 2 130 completed with an accuracy of  0.9219196062346188
# Forest Test:  0.15 gini 3 125 completed with an accuracy of  0.9826989335520918
# Forest Test:  0.15 gini 3 126 completed with an accuracy of  0.9827645611156685
# Forest Test:  0.15 gini 3 127 completed with an accuracy of  0.9836505332239547
# Forest Test:  0.15 gini 3 128 completed with an accuracy of  0.9825512715340445
# Forest Test:  0.15 gini 3 129 completed with an accuracy of  0.9829204265791631
# Forest Test:  0.15 gini 3 130 completed with an accuracy of  0.9830926989335523
# Forest Test:  0.15 gini 4 125 completed with an accuracy of  0.9902132895816241
# Forest Test:  0.15 gini 4 126 completed with an accuracy of  0.9902132895816245
# Forest Test:  0.15 gini 4 127 completed with an accuracy of  0.9901476620180472
# Forest Test:  0.15 gini 4 128 completed with an accuracy of  0.9896144380639866
# Forest Test:  0.15 gini 4 129 completed with an accuracy of  0.9900082034454469
# Forest Test:  0.15 gini 4 130 completed with an accuracy of  0.9898441345365048
# Forest Test:  0.15 gini 5 125 completed with an accuracy of  0.9902378999179655
# Forest Test:  0.15 gini 5 126 completed with an accuracy of  0.9906644790812138
# Forest Test:  0.15 gini 5 127 completed with an accuracy of  0.9908859721082856
# Forest Test:  0.15 gini 5 128 completed with an accuracy of  0.9904922067268253
# Forest Test:  0.15 gini 5 129 completed with an accuracy of  0.9908941755537325
# Forest Test:  0.15 gini 5 130 completed with an accuracy of  0.9906152584085316
# Forest Test:  0.15 gini 6 125 completed with an accuracy of  0.99363412633306
# Forest Test:  0.15 gini 6 126 completed with an accuracy of  0.9935931091058243
# Forest Test:  0.15 gini 6 127 completed with an accuracy of  0.9939294503691549
# Forest Test:  0.15 gini 6 128 completed with an accuracy of  0.9940278917145199
# Forest Test:  0.15 gini 6 129 completed with an accuracy of  0.9937489745693192
# Forest Test:  0.15 gini 6 130 completed with an accuracy of  0.9939212469237078
# Forest Test:  0.15 entropy 1 125 completed with an accuracy of  0.8934290401968827
# Forest Test:  0.15 entropy 1 126 completed with an accuracy of  0.8932485643970465
# Forest Test:  0.15 entropy 1 127 completed with an accuracy of  0.8947990155865466
# Forest Test:  0.15 entropy 1 128 completed with an accuracy of  0.8981952420016406
# Forest Test:  0.15 entropy 1 129 completed with an accuracy of  0.8933388022969649
# Forest Test:  0.15 entropy 1 130 completed with an accuracy of  0.8920672682526661
# Forest Test:  0.15 entropy 2 125 completed with an accuracy of  0.9195406070549629
# Forest Test:  0.15 entropy 2 126 completed with an accuracy of  0.9209680065627562
# Forest Test:  0.15 entropy 2 127 completed with an accuracy of  0.9200902378999178
# Forest Test:  0.15 entropy 2 128 completed with an accuracy of  0.9217145200984415
# Forest Test:  0.15 entropy 2 129 completed with an accuracy of  0.9211812961443805
# Forest Test:  0.15 entropy 2 130 completed with an accuracy of  0.919934372436423
# Forest Test:  0.15 entropy 3 125 completed with an accuracy of  0.9798031173092699
# Forest Test:  0.15 entropy 3 126 completed with an accuracy of  0.979630844954881
# Forest Test:  0.15 entropy 3 127 completed with an accuracy of  0.9808695652173917
# Forest Test:  0.15 entropy 3 128 completed with an accuracy of  0.9812551271534045
# Forest Test:  0.15 entropy 3 129 completed with an accuracy of  0.9818621821164889
# Forest Test:  0.15 entropy 3 130 completed with an accuracy of  0.9810664479081213
# Forest Test:  0.15 entropy 4 125 completed with an accuracy of  0.9902378999179651
# Forest Test:  0.15 entropy 4 126 completed with an accuracy of  0.9898933552091884
# Forest Test:  0.15 entropy 4 127 completed with an accuracy of  0.990098441345365
# Forest Test:  0.15 entropy 4 128 completed with an accuracy of  0.9898441345365053
# Forest Test:  0.15 entropy 4 129 completed with an accuracy of  0.9903199343724363
# Forest Test:  0.15 entropy 4 130 completed with an accuracy of  0.9902625102543068
# Forest Test:  0.15 entropy 5 125 completed with an accuracy of  0.9905250205086132
# Forest Test:  0.15 entropy 5 126 completed with an accuracy of  0.9901804757998359
# Forest Test:  0.15 entropy 5 127 completed with an accuracy of  0.9900410172272351
# Forest Test:  0.15 entropy 5 128 completed with an accuracy of  0.9899261689909769
# Forest Test:  0.15 entropy 5 129 completed with an accuracy of  0.9898523379819519
# Forest Test:  0.15 entropy 5 130 completed with an accuracy of  0.9905414273995079
# Forest Test:  0.15 entropy 6 125 completed with an accuracy of  0.9914438063986876
# Forest Test:  0.15 entropy 6 126 completed with an accuracy of  0.9921000820344544
# Forest Test:  0.15 entropy 6 127 completed with an accuracy of  0.9919442165709595
# Forest Test:  0.15 entropy 6 128 completed with an accuracy of  0.9915914684167348
# Forest Test:  0.15 entropy 6 129 completed with an accuracy of  0.992231337161608
# Forest Test:  0.15 entropy 6 130 completed with an accuracy of  0.9918211648892534
# Forest Test:  0.2 gini 1 125 completed with an accuracy of  0.882067692307692
# Forest Test:  0.2 gini 1 126 completed with an accuracy of  0.8817723076923076
# Forest Test:  0.2 gini 1 127 completed with an accuracy of  0.8823138461538461
# Forest Test:  0.2 gini 1 128 completed with an accuracy of  0.8824123076923079
# Forest Test:  0.2 gini 1 129 completed with an accuracy of  0.8830892307692308
# Forest Test:  0.2 gini 1 130 completed with an accuracy of  0.8861599999999997
# Forest Test:  0.2 gini 2 125 completed with an accuracy of  0.9230769230769235
# Forest Test:  0.2 gini 2 126 completed with an accuracy of  0.92192
# Forest Test:  0.2 gini 2 127 completed with an accuracy of  0.9213230769230768
# Forest Test:  0.2 gini 2 128 completed with an accuracy of  0.9231938461538465
# Forest Test:  0.2 gini 2 129 completed with an accuracy of  0.922566153846154
# Forest Test:  0.2 gini 2 130 completed with an accuracy of  0.921796923076923
# Forest Test:  0.2 gini 3 125 completed with an accuracy of  0.9829969230769234
# Forest Test:  0.2 gini 3 126 completed with an accuracy of  0.9831446153846153
# Forest Test:  0.2 gini 3 127 completed with an accuracy of  0.9829600000000001
# Forest Test:  0.2 gini 3 128 completed with an accuracy of  0.9827507692307691
# Forest Test:  0.2 gini 3 129 completed with an accuracy of  0.9840307692307694
# Forest Test:  0.2 gini 3 130 completed with an accuracy of  0.9837230769230768
# Forest Test:  0.2 gini 4 125 completed with an accuracy of  0.9903076923076922
# Forest Test:  0.2 gini 4 126 completed with an accuracy of  0.9897230769230768
# Forest Test:  0.2 gini 4 127 completed with an accuracy of  0.9895999999999995
# Forest Test:  0.2 gini 4 128 completed with an accuracy of  0.9899753846153844
# Forest Test:  0.2 gini 4 129 completed with an accuracy of  0.9903138461538465
# Forest Test:  0.2 gini 4 130 completed with an accuracy of  0.9900861538461535
# Forest Test:  0.2 gini 5 125 completed with an accuracy of  0.9905784615384612
# Forest Test:  0.2 gini 5 126 completed with an accuracy of  0.9910953846153845
# Forest Test:  0.2 gini 5 127 completed with an accuracy of  0.990756923076923
# Forest Test:  0.2 gini 5 128 completed with an accuracy of  0.990596923076923
# Forest Test:  0.2 gini 5 129 completed with an accuracy of  0.9902461538461541
# Forest Test:  0.2 gini 5 130 completed with an accuracy of  0.990436923076923
# Forest Test:  0.2 gini 6 125 completed with an accuracy of  0.9944246153846156
# Forest Test:  0.2 gini 6 126 completed with an accuracy of  0.9938153846153849
# Forest Test:  0.2 gini 6 127 completed with an accuracy of  0.9940923076923076
# Forest Test:  0.2 gini 6 128 completed with an accuracy of  0.9942092307692308
# Forest Test:  0.2 gini 6 129 completed with an accuracy of  0.9936246153846158
# Forest Test:  0.2 gini 6 130 completed with an accuracy of  0.9938646153846159
# Forest Test:  0.2 entropy 1 125 completed with an accuracy of  0.8937353846153847
# Forest Test:  0.2 entropy 1 126 completed with an accuracy of  0.8948738461538457
# Forest Test:  0.2 entropy 1 127 completed with an accuracy of  0.8943876923076924
# Forest Test:  0.2 entropy 1 128 completed with an accuracy of  0.8944307692307696
# Forest Test:  0.2 entropy 1 129 completed with an accuracy of  0.8953846153846153
# Forest Test:  0.2 entropy 1 130 completed with an accuracy of  0.8945476923076922
# Forest Test:  0.2 entropy 2 125 completed with an accuracy of  0.9216246153846157
# Forest Test:  0.2 entropy 2 126 completed with an accuracy of  0.9222461538461537
# Forest Test:  0.2 entropy 2 127 completed with an accuracy of  0.9188923076923075
# Forest Test:  0.2 entropy 2 128 completed with an accuracy of  0.922
# Forest Test:  0.2 entropy 2 129 completed with an accuracy of  0.9212123076923074
# Forest Test:  0.2 entropy 2 130 completed with an accuracy of  0.9207507692307694
# Forest Test:  0.2 entropy 3 125 completed with an accuracy of  0.9797846153846159
# Forest Test:  0.2 entropy 3 126 completed with an accuracy of  0.9816861538461537
# Forest Test:  0.2 entropy 3 127 completed with an accuracy of  0.9803138461538465
# Forest Test:  0.2 entropy 3 128 completed with an accuracy of  0.9818953846153845
# Forest Test:  0.2 entropy 3 129 completed with an accuracy of  0.9803815384615387
# Forest Test:  0.2 entropy 3 130 completed with an accuracy of  0.9811200000000002
# Forest Test:  0.2 entropy 4 125 completed with an accuracy of  0.9896246153846149
# Forest Test:  0.2 entropy 4 126 completed with an accuracy of  0.990006153846154
# Forest Test:  0.2 entropy 4 127 completed with an accuracy of  0.9896799999999996
# Forest Test:  0.2 entropy 4 128 completed with an accuracy of  0.9895630769230764
# Forest Test:  0.2 entropy 4 129 completed with an accuracy of  0.990030769230769
# Forest Test:  0.2 entropy 4 130 completed with an accuracy of  0.9896923076923072
# Forest Test:  0.2 entropy 5 125 completed with an accuracy of  0.9901907692307687
# Forest Test:  0.2 entropy 5 126 completed with an accuracy of  0.9901538461538459
# Forest Test:  0.2 entropy 5 127 completed with an accuracy of  0.9903630769230767
# Forest Test:  0.2 entropy 5 128 completed with an accuracy of  0.9904984615384614
# Forest Test:  0.2 entropy 5 129 completed with an accuracy of  0.9902215384615382
# Forest Test:  0.2 entropy 5 130 completed with an accuracy of  0.9903507692307691
# Forest Test:  0.2 entropy 6 125 completed with an accuracy of  0.9921107692307689
# Forest Test:  0.2 entropy 6 126 completed with an accuracy of  0.9914646153846155
# Forest Test:  0.2 entropy 6 127 completed with an accuracy of  0.9918523076923081
# Forest Test:  0.2 entropy 6 128 completed with an accuracy of  0.9916184615384617
# Forest Test:  0.2 entropy 6 129 completed with an accuracy of  0.991883076923077
# Forest Test:  0.2 entropy 6 130 completed with an accuracy of  0.9921230769230772
# Forest Test:  0.25 gini 1 125 completed with an accuracy of  0.8819694731659282
# Forest Test:  0.25 gini 1 126 completed with an accuracy of  0.8842540620384046
# Forest Test:  0.25 gini 1 127 completed with an accuracy of  0.8787592319054659
# Forest Test:  0.25 gini 1 128 completed with an accuracy of  0.8831610044313147
# Forest Test:  0.25 gini 1 129 completed with an accuracy of  0.8843279172821268
# Forest Test:  0.25 gini 1 130 completed with an accuracy of  0.8832200886262921
# Forest Test:  0.25 gini 2 125 completed with an accuracy of  0.9227523387493842
# Forest Test:  0.25 gini 2 126 completed with an accuracy of  0.9227178729689812
# Forest Test:  0.25 gini 2 127 completed with an accuracy of  0.921880846873461
# Forest Test:  0.25 gini 2 128 completed with an accuracy of  0.9215706548498279
# Forest Test:  0.25 gini 2 129 completed with an accuracy of  0.9230969965534225
# Forest Test:  0.25 gini 2 130 completed with an accuracy of  0.9232348596750367
# Forest Test:  0.25 gini 3 125 completed with an accuracy of  0.9829148202855733
# Forest Test:  0.25 gini 3 126 completed with an accuracy of  0.9833431806991629
# Forest Test:  0.25 gini 3 127 completed with an accuracy of  0.9828360413589362
# Forest Test:  0.25 gini 3 128 completed with an accuracy of  0.9822796651895617
# Forest Test:  0.25 gini 3 129 completed with an accuracy of  0.9830083702609552
# Forest Test:  0.25 gini 3 130 completed with an accuracy of  0.9823289020187097
# Forest Test:  0.25 gini 4 125 completed with an accuracy of  0.9900738552437224
# Forest Test:  0.25 gini 4 126 completed with an accuracy of  0.9901033973412106
# Forest Test:  0.25 gini 4 127 completed with an accuracy of  0.9901033973412112
# Forest Test:  0.25 gini 4 128 completed with an accuracy of  0.9898129000492366
# Forest Test:  0.25 gini 4 129 completed with an accuracy of  0.9897193500738551
# Forest Test:  0.25 gini 4 130 completed with an accuracy of  0.9899655342195962
# Forest Test:  0.25 gini 5 125 completed with an accuracy of  0.9907139340226486
# Forest Test:  0.25 gini 5 126 completed with an accuracy of  0.9908370260955192
# Forest Test:  0.25 gini 5 127 completed with an accuracy of  0.9902904972919743
# Forest Test:  0.25 gini 5 128 completed with an accuracy of  0.9904726735598227
# Forest Test:  0.25 gini 5 129 completed with an accuracy of  0.9906696208764154
# Forest Test:  0.25 gini 5 130 completed with an accuracy of  0.990738552437223
# Forest Test:  0.25 gini 6 125 completed with an accuracy of  0.9940472673559825
# Forest Test:  0.25 gini 6 126 completed with an accuracy of  0.994426390940424
# Forest Test:  0.25 gini 6 127 completed with an accuracy of  0.9938306253077304
# Forest Test:  0.25 gini 6 128 completed with an accuracy of  0.994086656819301
# Forest Test:  0.25 gini 6 129 completed with an accuracy of  0.9936976858690306
# Forest Test:  0.25 gini 6 130 completed with an accuracy of  0.9939684884293452
# Forest Test:  0.25 entropy 1 125 completed with an accuracy of  0.8940275726243232
# Forest Test:  0.25 entropy 1 126 completed with an accuracy of  0.8906450024618414
# Forest Test:  0.25 entropy 1 127 completed with an accuracy of  0.8949384539635643
# Forest Test:  0.25 entropy 1 128 completed with an accuracy of  0.8930083702609554
# Forest Test:  0.25 entropy 1 129 completed with an accuracy of  0.8928409650418513
# Forest Test:  0.25 entropy 1 130 completed with an accuracy of  0.8966912850812406
# Forest Test:  0.25 entropy 2 125 completed with an accuracy of  0.9206991629739045
# Forest Test:  0.25 entropy 2 126 completed with an accuracy of  0.9207828655834566
# Forest Test:  0.25 entropy 2 127 completed with an accuracy of  0.9195617922205811
# Forest Test:  0.25 entropy 2 128 completed with an accuracy of  0.9214820285573612
# Forest Test:  0.25 entropy 2 129 completed with an accuracy of  0.9203938946331857
# Forest Test:  0.25 entropy 2 130 completed with an accuracy of  0.9207237813884784
# Forest Test:  0.25 entropy 3 125 completed with an accuracy of  0.9805465288035454
# Forest Test:  0.25 entropy 3 126 completed with an accuracy of  0.982072870507139
# Forest Test:  0.25 entropy 3 127 completed with an accuracy of  0.9807188577055631
# Forest Test:  0.25 entropy 3 128 completed with an accuracy of  0.9800344657804034
# Forest Test:  0.25 entropy 3 129 completed with an accuracy of  0.9798473658296402
# Forest Test:  0.25 entropy 3 130 completed with an accuracy of  0.9819694731659283
# Forest Test:  0.25 entropy 4 125 completed with an accuracy of  0.9896110290497289
# Forest Test:  0.25 entropy 4 126 completed with an accuracy of  0.9898966026587889
# Forest Test:  0.25 entropy 4 127 completed with an accuracy of  0.9898818316100437
# Forest Test:  0.25 entropy 4 128 completed with an accuracy of  0.9899753815854261
# Forest Test:  0.25 entropy 4 129 completed with an accuracy of  0.9901132447070409
# Forest Test:  0.25 entropy 4 130 completed with an accuracy of  0.9900541605120631
# Forest Test:  0.25 entropy 5 125 completed with an accuracy of  0.99055145248646
# Forest Test:  0.25 entropy 5 126 completed with an accuracy of  0.9901575578532744
# Forest Test:  0.25 entropy 5 127 completed with an accuracy of  0.9903643525356962
# Forest Test:  0.25 entropy 5 128 completed with an accuracy of  0.9905662235352044
# Forest Test:  0.25 entropy 5 129 completed with an accuracy of  0.9903545051698671
# Forest Test:  0.25 entropy 5 130 completed with an accuracy of  0.9901772525849336
# Forest Test:  0.25 entropy 6 125 completed with an accuracy of  0.9920187099950765
# Forest Test:  0.25 entropy 6 126 completed with an accuracy of  0.9917380600689314
# Forest Test:  0.25 entropy 6 127 completed with an accuracy of  0.9917922205809947
# Forest Test:  0.25 entropy 6 128 completed with an accuracy of  0.9920827178729696
# Forest Test:  0.25 entropy 6 129 completed with an accuracy of  0.9921073362875426
# Forest Test:  0.25 entropy 6 130 completed with an accuracy of  0.9919005416051209
# Forest Test:  0.3 gini 1 125 completed with an accuracy of  0.8827153404429857
# Forest Test:  0.3 gini 1 126 completed with an accuracy of  0.884208367514356
# Forest Test:  0.3 gini 1 127 completed with an accuracy of  0.88332239540607
# Forest Test:  0.3 gini 1 128 completed with an accuracy of  0.8838556193601308
# Forest Test:  0.3 gini 1 129 completed with an accuracy of  0.8817883511074647
# Forest Test:  0.3 gini 1 130 completed with an accuracy of  0.8834167350287119
# Forest Test:  0.3 gini 2 125 completed with an accuracy of  0.922932731747334
# Forest Test:  0.3 gini 2 126 completed with an accuracy of  0.922288761279737
# Forest Test:  0.3 gini 2 127 completed with an accuracy of  0.9230803937653819
# Forest Test:  0.3 gini 2 128 completed with an accuracy of  0.9214068908941758
# Forest Test:  0.3 gini 2 129 completed with an accuracy of  0.9229819524200168
# Forest Test:  0.3 gini 2 130 completed with an accuracy of  0.9237489745693191
# Forest Test:  0.3 gini 3 125 completed with an accuracy of  0.9827768662838393
# Forest Test:  0.3 gini 3 126 completed with an accuracy of  0.9824118129614444
# Forest Test:  0.3 gini 3 127 completed with an accuracy of  0.981825266611977
# Forest Test:  0.3 gini 3 128 completed with an accuracy of  0.9820344544708779
# Forest Test:  0.3 gini 3 129 completed with an accuracy of  0.9823379819524198
# Forest Test:  0.3 gini 3 130 completed with an accuracy of  0.9820057424118125
# Forest Test:  0.3 gini 4 125 completed with an accuracy of  0.9898113207547169
# Forest Test:  0.3 gini 4 126 completed with an accuracy of  0.9900615258408536
# Forest Test:  0.3 gini 4 127 completed with an accuracy of  0.9900205086136173
# Forest Test:  0.3 gini 4 128 completed with an accuracy of  0.9898523379819524
# Forest Test:  0.3 gini 4 129 completed with an accuracy of  0.9901722723543885
# Forest Test:  0.3 gini 4 130 completed with an accuracy of  0.9901476620180477
# Forest Test:  0.3 gini 5 125 completed with an accuracy of  0.990988515176374
# Forest Test:  0.3 gini 5 126 completed with an accuracy of  0.9904881050041019
# Forest Test:  0.3 gini 5 127 completed with an accuracy of  0.9904963084495491
# Forest Test:  0.3 gini 5 128 completed with an accuracy of  0.9902255947497948
# Forest Test:  0.3 gini 5 129 completed with an accuracy of  0.9908121410992617
# Forest Test:  0.3 gini 5 130 completed with an accuracy of  0.9906808859721083
# Forest Test:  0.3 gini 6 125 completed with an accuracy of  0.9935028712059064
# Forest Test:  0.3 gini 6 126 completed with an accuracy of  0.9937038556193604
# Forest Test:  0.3 gini 6 127 completed with an accuracy of  0.993794093519278
# Forest Test:  0.3 gini 6 128 completed with an accuracy of  0.9939704675963904
# Forest Test:  0.3 gini 6 129 completed with an accuracy of  0.9938966365873665
# Forest Test:  0.3 gini 6 130 completed with an accuracy of  0.9934905660377357
# Forest Test:  0.3 entropy 1 125 completed with an accuracy of  0.8946144380639871
# Forest Test:  0.3 entropy 1 126 completed with an accuracy of  0.8929819524200165
# Forest Test:  0.3 entropy 1 127 completed with an accuracy of  0.893129614438064
# Forest Test:  0.3 entropy 1 128 completed with an accuracy of  0.893597210828548
# Forest Test:  0.3 entropy 1 129 completed with an accuracy of  0.8937407711238721
# Forest Test:  0.3 entropy 1 130 completed with an accuracy of  0.8936628383921249
# Forest Test:  0.3 entropy 2 125 completed with an accuracy of  0.9197826086956519
# Forest Test:  0.3 entropy 2 126 completed with an accuracy of  0.9196308449548813
# Forest Test:  0.3 entropy 2 127 completed with an accuracy of  0.9183552091878593
# Forest Test:  0.3 entropy 2 128 completed with an accuracy of  0.9181009023789993
# Forest Test:  0.3 entropy 2 129 completed with an accuracy of  0.9217801476620179
# Forest Test:  0.3 entropy 2 130 completed with an accuracy of  0.921115668580804
# Forest Test:  0.3 entropy 3 125 completed with an accuracy of  0.9799753896636587
# Forest Test:  0.3 entropy 3 126 completed with an accuracy of  0.9799302707137
# Forest Test:  0.3 entropy 3 127 completed with an accuracy of  0.9801927809680063
# Forest Test:  0.3 entropy 3 128 completed with an accuracy of  0.9809310910582443
# Forest Test:  0.3 entropy 3 129 completed with an accuracy of  0.9796759639048406
# Forest Test:  0.3 entropy 3 130 completed with an accuracy of  0.9808080393765387
# Forest Test:  0.3 entropy 4 125 completed with an accuracy of  0.9900861361771947
# Forest Test:  0.3 entropy 4 126 completed with an accuracy of  0.9897744052502051
# Forest Test:  0.3 entropy 4 127 completed with an accuracy of  0.9902173913043478
# Forest Test:  0.3 entropy 4 128 completed with an accuracy of  0.9896431501230513
# Forest Test:  0.3 entropy 4 129 completed with an accuracy of  0.9899671862182116
# Forest Test:  0.3 entropy 4 130 completed with an accuracy of  0.9901763740771122
# Forest Test:  0.3 entropy 5 125 completed with an accuracy of  0.9901476620180476
# Forest Test:  0.3 entropy 5 126 completed with an accuracy of  0.990529122231337
# Forest Test:  0.3 entropy 5 127 completed with an accuracy of  0.9902132895816242
# Forest Test:  0.3 entropy 5 128 completed with an accuracy of  0.9904306808859716
# Forest Test:  0.3 entropy 5 129 completed with an accuracy of  0.990180475799836
# Forest Test:  0.3 entropy 5 130 completed with an accuracy of  0.990242001640689
# Forest Test:  0.3 entropy 6 125 completed with an accuracy of  0.9917596390484007
# Forest Test:  0.3 entropy 6 126 completed with an accuracy of  0.9916078753076286
# Forest Test:  0.3 entropy 6 127 completed with an accuracy of  0.991878589007383
# Forest Test:  0.3 entropy 6 128 completed with an accuracy of  0.991882690730106
# Forest Test:  0.3 entropy 6 129 completed with an accuracy of  0.9919196062346185
# Forest Test:  0.3 entropy 6 130 completed with an accuracy of  0.9919729286300246
# Forest Test:  0.35 gini 1 125 completed with an accuracy of  0.8806715893108296
# Forest Test:  0.35 gini 1 126 completed with an accuracy of  0.8839592123769338
# Forest Test:  0.35 gini 1 127 completed with an accuracy of  0.8833157524613217
# Forest Test:  0.35 gini 1 128 completed with an accuracy of  0.8841385372714491
# Forest Test:  0.35 gini 1 129 completed with an accuracy of  0.8849050632911392
# Forest Test:  0.35 gini 1 130 completed with an accuracy of  0.8818776371308019
# Forest Test:  0.35 gini 2 125 completed with an accuracy of  0.9218178621659635
# Forest Test:  0.35 gini 2 126 completed with an accuracy of  0.924521800281294
# Forest Test:  0.35 gini 2 127 completed with an accuracy of  0.9231399437412092
# Forest Test:  0.35 gini 2 128 completed with an accuracy of  0.9212658227848098
# Forest Test:  0.35 gini 2 129 completed with an accuracy of  0.9229219409282698
# Forest Test:  0.35 gini 2 130 completed with an accuracy of  0.9223241912798867
# Forest Test:  0.35 gini 3 125 completed with an accuracy of  0.9833473980309422
# Forest Test:  0.35 gini 3 126 completed with an accuracy of  0.9825035161744023
# Forest Test:  0.35 gini 3 127 completed with an accuracy of  0.9824507735583689
# Forest Test:  0.35 gini 3 128 completed with an accuracy of  0.9832102672292544
# Forest Test:  0.35 gini 3 129 completed with an accuracy of  0.9831610407876235
# Forest Test:  0.35 gini 3 130 completed with an accuracy of  0.9830344585091426
# Forest Test:  0.35 gini 4 125 completed with an accuracy of  0.9900492264416314
# Forest Test:  0.35 gini 4 126 completed with an accuracy of  0.9899683544303801
# Forest Test:  0.35 gini 4 127 completed with an accuracy of  0.9896940928270045
# Forest Test:  0.35 gini 4 128 completed with an accuracy of  0.9901582278481016
# Forest Test:  0.35 gini 4 129 completed with an accuracy of  0.9899120956399448
# Forest Test:  0.35 gini 4 130 completed with an accuracy of  0.9900000000000003
# Forest Test:  0.35 gini 5 125 completed with an accuracy of  0.9903551336146275
# Forest Test:  0.35 gini 5 126 completed with an accuracy of  0.9904500703234882
# Forest Test:  0.35 gini 5 127 completed with an accuracy of  0.9907102672292549
# Forest Test:  0.35 gini 5 128 completed with an accuracy of  0.9903832630098459
# Forest Test:  0.35 gini 5 129 completed with an accuracy of  0.9906012658227845
# Forest Test:  0.35 gini 5 130 completed with an accuracy of  0.9905731364275675
# Forest Test:  0.35 gini 6 125 completed with an accuracy of  0.9936954992967653
# Forest Test:  0.35 gini 6 126 completed with an accuracy of  0.9940014064697611
# Forest Test:  0.35 gini 6 127 completed with an accuracy of  0.993994374120957
# Forest Test:  0.35 gini 6 128 completed with an accuracy of  0.9942440225035163
# Forest Test:  0.35 gini 6 129 completed with an accuracy of  0.9938537271448663
# Forest Test:  0.35 gini 6 130 completed with an accuracy of  0.993748241912799
# Forest Test:  0.35 entropy 1 125 completed with an accuracy of  0.8930731364275666
# Forest Test:  0.35 entropy 1 126 completed with an accuracy of  0.8943389592123769
# Forest Test:  0.35 entropy 1 127 completed with an accuracy of  0.889954289732771
# Forest Test:  0.35 entropy 1 128 completed with an accuracy of  0.8932419127988741
# Forest Test:  0.35 entropy 1 129 completed with an accuracy of  0.8924472573839658
# Forest Test:  0.35 entropy 1 130 completed with an accuracy of  0.8911392405063284
# Forest Test:  0.35 entropy 2 125 completed with an accuracy of  0.9197538677918421
# Forest Test:  0.35 entropy 2 126 completed with an accuracy of  0.9218354430379744
# Forest Test:  0.35 entropy 2 127 completed with an accuracy of  0.9205485232067505
# Forest Test:  0.35 entropy 2 128 completed with an accuracy of  0.9195745428973272
# Forest Test:  0.35 entropy 2 129 completed with an accuracy of  0.9169409282700417
# Forest Test:  0.35 entropy 2 130 completed with an accuracy of  0.9193248945147678
# Forest Test:  0.35 entropy 3 125 completed with an accuracy of  0.9796940928270044
# Forest Test:  0.35 entropy 3 126 completed with an accuracy of  0.9785970464135025
# Forest Test:  0.35 entropy 3 127 completed with an accuracy of  0.9806645569620258
# Forest Test:  0.35 entropy 3 128 completed with an accuracy of  0.9804113924050636
# Forest Test:  0.35 entropy 3 129 completed with an accuracy of  0.9814064697609006
# Forest Test:  0.35 entropy 3 130 completed with an accuracy of  0.9803129395218008
# Forest Test:  0.35 entropy 4 125 completed with an accuracy of  0.989982419127989
# Forest Test:  0.35 entropy 4 126 completed with an accuracy of  0.9898347398030944
# Forest Test:  0.35 entropy 4 127 completed with an accuracy of  0.9898945147679324
# Forest Test:  0.35 entropy 4 128 completed with an accuracy of  0.9900773558368495
# Forest Test:  0.35 entropy 4 129 completed with an accuracy of  0.9897925457102678
# Forest Test:  0.35 entropy 4 130 completed with an accuracy of  0.9899894514767937
# Forest Test:  0.35 entropy 5 125 completed with an accuracy of  0.9903129395218003
# Forest Test:  0.35 entropy 5 126 completed with an accuracy of  0.9902390998593531
# Forest Test:  0.35 entropy 5 127 completed with an accuracy of  0.9904500703234881
# Forest Test:  0.35 entropy 5 128 completed with an accuracy of  0.990316455696203
# Forest Test:  0.35 entropy 5 129 completed with an accuracy of  0.9903832630098457
# Forest Test:  0.35 entropy 5 130 completed with an accuracy of  0.9900668073136428
# Forest Test:  0.35 entropy 6 125 completed with an accuracy of  0.9918143459915615
# Forest Test:  0.35 entropy 6 126 completed with an accuracy of  0.9917088607594938
# Forest Test:  0.35 entropy 6 127 completed with an accuracy of  0.9920464135021096
# Forest Test:  0.35 entropy 6 128 completed with an accuracy of  0.9919514767932491
# Forest Test:  0.35 entropy 6 129 completed with an accuracy of  0.9917510548523208
# Forest Test:  0.35 entropy 6 130 completed with an accuracy of  0.9915506329113929
# Forest Test:  0.4 gini 1 125 completed with an accuracy of  0.8839107692307695
# Forest Test:  0.4 gini 1 126 completed with an accuracy of  0.8844369230769228
# Forest Test:  0.4 gini 1 127 completed with an accuracy of  0.8840492307692307
# Forest Test:  0.4 gini 1 128 completed with an accuracy of  0.8828276923076921
# Forest Test:  0.4 gini 1 129 completed with an accuracy of  0.882393846153846
# Forest Test:  0.4 gini 1 130 completed with an accuracy of  0.8821076923076926
# Forest Test:  0.4 gini 2 125 completed with an accuracy of  0.921138461538461
# Forest Test:  0.4 gini 2 126 completed with an accuracy of  0.9225384615384614
# Forest Test:  0.4 gini 2 127 completed with an accuracy of  0.9227261538461542
# Forest Test:  0.4 gini 2 128 completed with an accuracy of  0.922316923076923
# Forest Test:  0.4 gini 2 129 completed with an accuracy of  0.921898461538461
# Forest Test:  0.4 gini 2 130 completed with an accuracy of  0.9231538461538463
# Forest Test:  0.4 gini 3 125 completed with an accuracy of  0.9832338461538463
# Forest Test:  0.4 gini 3 126 completed with an accuracy of  0.9830276923076923
# Forest Test:  0.4 gini 3 127 completed with an accuracy of  0.9829169230769229
# Forest Test:  0.4 gini 3 128 completed with an accuracy of  0.9825384615384618
# Forest Test:  0.4 gini 3 129 completed with an accuracy of  0.9814861538461542
# Forest Test:  0.4 gini 3 130 completed with an accuracy of  0.9831292307692313
# Forest Test:  0.4 gini 4 125 completed with an accuracy of  0.9898984615384618
# Forest Test:  0.4 gini 4 126 completed with an accuracy of  0.9899507692307695
# Forest Test:  0.4 gini 4 127 completed with an accuracy of  0.9899907692307695
# Forest Test:  0.4 gini 4 128 completed with an accuracy of  0.989892307692308
# Forest Test:  0.4 gini 4 129 completed with an accuracy of  0.9899538461538462
# Forest Test:  0.4 gini 4 130 completed with an accuracy of  0.9901046153846156
# Forest Test:  0.4 gini 5 125 completed with an accuracy of  0.9901999999999996
# Forest Test:  0.4 gini 5 126 completed with an accuracy of  0.9907323076923075
# Forest Test:  0.4 gini 5 127 completed with an accuracy of  0.99031076923077
# Forest Test:  0.4 gini 5 128 completed with an accuracy of  0.9908215384615384
# Forest Test:  0.4 gini 5 129 completed with an accuracy of  0.9905446153846154
# Forest Test:  0.4 gini 5 130 completed with an accuracy of  0.9904492307692309
# Forest Test:  0.4 gini 6 125 completed with an accuracy of  0.9940769230769229
# Forest Test:  0.4 gini 6 126 completed with an accuracy of  0.9937538461538463
# Forest Test:  0.4 gini 6 127 completed with an accuracy of  0.9938184615384614
# Forest Test:  0.4 gini 6 128 completed with an accuracy of  0.9940369230769234
# Forest Test:  0.4 gini 6 129 completed with an accuracy of  0.9938830769230766
# Forest Test:  0.4 gini 6 130 completed with an accuracy of  0.9936123076923079
# Forest Test:  0.4 entropy 1 125 completed with an accuracy of  0.8939753846153846
# Forest Test:  0.4 entropy 1 126 completed with an accuracy of  0.8944923076923079
# Forest Test:  0.4 entropy 1 127 completed with an accuracy of  0.8920030769230776
# Forest Test:  0.4 entropy 1 128 completed with an accuracy of  0.8902092307692309
# Forest Test:  0.4 entropy 1 129 completed with an accuracy of  0.8924769230769226
# Forest Test:  0.4 entropy 1 130 completed with an accuracy of  0.8938553846153848
# Forest Test:  0.4 entropy 2 125 completed with an accuracy of  0.922212307692308
# Forest Test:  0.4 entropy 2 126 completed with an accuracy of  0.921726153846154
# Forest Test:  0.4 entropy 2 127 completed with an accuracy of  0.9214369230769226
# Forest Test:  0.4 entropy 2 128 completed with an accuracy of  0.9223815384615386
# Forest Test:  0.4 entropy 2 129 completed with an accuracy of  0.9219015384615384
# Forest Test:  0.4 entropy 2 130 completed with an accuracy of  0.9208369230769224
# Forest Test:  0.4 entropy 3 125 completed with an accuracy of  0.9784092307692306
# Forest Test:  0.4 entropy 3 126 completed with an accuracy of  0.9791107692307692
# Forest Test:  0.4 entropy 3 127 completed with an accuracy of  0.9823538461538465
# Forest Test:  0.4 entropy 3 128 completed with an accuracy of  0.9794338461538463
# Forest Test:  0.4 entropy 3 129 completed with an accuracy of  0.98052
# Forest Test:  0.4 entropy 3 130 completed with an accuracy of  0.9794953846153845
# Forest Test:  0.4 entropy 4 125 completed with an accuracy of  0.9900092307692308
# Forest Test:  0.4 entropy 4 126 completed with an accuracy of  0.9895876923076924
# Forest Test:  0.4 entropy 4 127 completed with an accuracy of  0.9897753846153848
# Forest Test:  0.4 entropy 4 128 completed with an accuracy of  0.989723076923077
# Forest Test:  0.4 entropy 4 129 completed with an accuracy of  0.9899384615384612
# Forest Test:  0.4 entropy 4 130 completed with an accuracy of  0.9900646153846158
# Forest Test:  0.4 entropy 5 125 completed with an accuracy of  0.9903138461538467
# Forest Test:  0.4 entropy 5 126 completed with an accuracy of  0.9898984615384618
# Forest Test:  0.4 entropy 5 127 completed with an accuracy of  0.9902430769230769
# Forest Test:  0.4 entropy 5 128 completed with an accuracy of  0.9900492307692309
# Forest Test:  0.4 entropy 5 129 completed with an accuracy of  0.9901015384615383
# Forest Test:  0.4 entropy 5 130 completed with an accuracy of  0.9899292307692308
# Forest Test:  0.4 entropy 6 125 completed with an accuracy of  0.9919046153846159
# Forest Test:  0.4 entropy 6 126 completed with an accuracy of  0.9920153846153851
# Forest Test:  0.4 entropy 6 127 completed with an accuracy of  0.9917138461538461
# Forest Test:  0.4 entropy 6 128 completed with an accuracy of  0.9919600000000003
# Forest Test:  0.4 entropy 6 129 completed with an accuracy of  0.9919999999999998
# Forest Test:  0.4 entropy 6 130 completed with an accuracy of  0.9917999999999997
# Forest Test:  0.45 gini 1 125 completed with an accuracy of  0.88371170678337
# Forest Test:  0.45 gini 1 126 completed with an accuracy of  0.8826258205689278
# Forest Test:  0.45 gini 1 127 completed with an accuracy of  0.8828145514223198
# Forest Test:  0.45 gini 1 128 completed with an accuracy of  0.8815207877461709
# Forest Test:  0.45 gini 1 129 completed with an accuracy of  0.8805005470459512
# Forest Test:  0.45 gini 1 130 completed with an accuracy of  0.8818845733041576
# Forest Test:  0.45 gini 2 125 completed with an accuracy of  0.9241247264770241
# Forest Test:  0.45 gini 2 126 completed with an accuracy of  0.9226613785557986
# Forest Test:  0.45 gini 2 127 completed with an accuracy of  0.9225574398249452
# Forest Test:  0.45 gini 2 128 completed with an accuracy of  0.9205087527352299
# Forest Test:  0.45 gini 2 129 completed with an accuracy of  0.9242040481400434
# Forest Test:  0.45 gini 2 130 completed with an accuracy of  0.9242149890590808
# Forest Test:  0.45 gini 3 125 completed with an accuracy of  0.9829458424507662
# Forest Test:  0.45 gini 3 126 completed with an accuracy of  0.9820404814004382
# Forest Test:  0.45 gini 3 127 completed with an accuracy of  0.982718818380744
# Forest Test:  0.45 gini 3 128 completed with an accuracy of  0.9819256017505466
# Forest Test:  0.45 gini 3 129 completed with an accuracy of  0.9826586433260394
# Forest Test:  0.45 gini 3 130 completed with an accuracy of  0.9816657549234131
# Forest Test:  0.45 gini 4 125 completed with an accuracy of  0.9901148796498909
# Forest Test:  0.45 gini 4 126 completed with an accuracy of  0.9902133479212251
# Forest Test:  0.45 gini 4 127 completed with an accuracy of  0.9899124726477028
# Forest Test:  0.45 gini 4 128 completed with an accuracy of  0.9900164113785561
# Forest Test:  0.45 gini 4 129 completed with an accuracy of  0.9896362144420133
# Forest Test:  0.45 gini 4 130 completed with an accuracy of  0.989904266958425
# Forest Test:  0.45 gini 5 125 completed with an accuracy of  0.9907029540481403
# Forest Test:  0.45 gini 5 126 completed with an accuracy of  0.9905415754923413
# Forest Test:  0.45 gini 5 127 completed with an accuracy of  0.9905114879649889
# Forest Test:  0.45 gini 5 128 completed with an accuracy of  0.9904759299781183
# Forest Test:  0.45 gini 5 129 completed with an accuracy of  0.9902571115973748
# Forest Test:  0.45 gini 5 130 completed with an accuracy of  0.9906427789934356
# Forest Test:  0.45 gini 6 125 completed with an accuracy of  0.9936132385120346
# Forest Test:  0.45 gini 6 126 completed with an accuracy of  0.9937335886214437
# Forest Test:  0.45 gini 6 127 completed with an accuracy of  0.993990700218818
# Forest Test:  0.45 gini 6 128 completed with an accuracy of  0.9938293216630198
# Forest Test:  0.45 gini 6 129 completed with an accuracy of  0.993862144420131
# Forest Test:  0.45 gini 6 130 completed with an accuracy of  0.9940590809628008
# Forest Test:  0.45 entropy 1 125 completed with an accuracy of  0.8924452954048141
# Forest Test:  0.45 entropy 1 126 completed with an accuracy of  0.8933014223194746
# Forest Test:  0.45 entropy 1 127 completed with an accuracy of  0.8912253829321664
# Forest Test:  0.45 entropy 1 128 completed with an accuracy of  0.8934463894967176
# Forest Test:  0.45 entropy 1 129 completed with an accuracy of  0.8937828227571113
# Forest Test:  0.45 entropy 1 130 completed with an accuracy of  0.8928665207877464
# Forest Test:  0.45 entropy 2 125 completed with an accuracy of  0.9217040481400437
# Forest Test:  0.45 entropy 2 126 completed with an accuracy of  0.9250492341356675
# Forest Test:  0.45 entropy 2 127 completed with an accuracy of  0.9212527352297593
# Forest Test:  0.45 entropy 2 128 completed with an accuracy of  0.9220021881838072
# Forest Test:  0.45 entropy 2 129 completed with an accuracy of  0.9243544857768053
# Forest Test:  0.45 entropy 2 130 completed with an accuracy of  0.9222811816192561
# Forest Test:  0.45 entropy 3 125 completed with an accuracy of  0.9792587527352298
# Forest Test:  0.45 entropy 3 126 completed with an accuracy of  0.9784956236323855
# Forest Test:  0.45 entropy 3 127 completed with an accuracy of  0.9808807439824944
# Forest Test:  0.45 entropy 3 128 completed with an accuracy of  0.9799753829321662
# Forest Test:  0.45 entropy 3 129 completed with an accuracy of  0.9795213347921226
# Forest Test:  0.45 entropy 3 130 completed with an accuracy of  0.9790727571115977
# Forest Test:  0.45 entropy 4 125 completed with an accuracy of  0.9897456236323856
# Forest Test:  0.45 entropy 4 126 completed with an accuracy of  0.9896854485776808
# Forest Test:  0.45 entropy 4 127 completed with an accuracy of  0.9899042669584243
# Forest Test:  0.45 entropy 4 128 completed with an accuracy of  0.989576039387309
# Forest Test:  0.45 entropy 4 129 completed with an accuracy of  0.989819474835886
# Forest Test:  0.45 entropy 4 130 completed with an accuracy of  0.9898386214442018
# Forest Test:  0.45 entropy 5 125 completed with an accuracy of  0.9902324945295407
# Forest Test:  0.45 entropy 5 126 completed with an accuracy of  0.9901094091903722
# Forest Test:  0.45 entropy 5 127 completed with an accuracy of  0.9903966083150985
# Forest Test:  0.45 entropy 5 128 completed with an accuracy of  0.990325492341357
# Forest Test:  0.45 entropy 5 129 completed with an accuracy of  0.9902024070021881
# Forest Test:  0.45 entropy 5 130 completed with an accuracy of  0.9901094091903718
# Forest Test:  0.45 entropy 6 125 completed with an accuracy of  0.9918818380743981
# Forest Test:  0.45 entropy 6 126 completed with an accuracy of  0.9918763676148794
# Forest Test:  0.45 entropy 6 127 completed with an accuracy of  0.9917532822757111
# Forest Test:  0.45 entropy 6 128 completed with an accuracy of  0.9918435448577685
# Forest Test:  0.45 entropy 6 129 completed with an accuracy of  0.9919474835886216
# Forest Test:  0.45 entropy 6 130 completed with an accuracy of  0.9919502188183804
